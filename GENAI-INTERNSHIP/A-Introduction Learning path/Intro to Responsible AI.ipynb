# %% [markdown]
# INTRO TO RESPONSIBLE AI

# %% [raw]
# Responsible AI is all about developing and deploying AI in ways that are ethical, fair, transparent, and accountable.

# %% [raw]
# Developing AI requires an understanding of the possible issues,limitations or unintended consequences

# %% [raw]
# all companies have some common ai practices transparency,fairness,accountability and privacy

# %% [raw]
# Responsibility by design

# %% [raw]
# Every decision point requires consideration and evaluation to ensure that choices have been made responsibily from concept to deployment and maintainence

# %% [raw]
# Responsible AI = Successful AI

# %% [raw]
# june 2018 google announced 7 ai principles
# AI should

# %% [raw]
# be socially beneficial

# %% [raw]
# Avoid creating or reinforcing unfair bias

# %% [raw]
# Be build and tested for safety

# %% [raw]
# Be accountable to people

# %% [raw]
# Incorporate privacy design principles

# %% [raw]
# uphold high standards of scientific excellence

# %% [raw]
# be made available for uses that accord with these principles

# %% [markdown]
# ![image.png](attachment:0b3a4988-3503-4e74-94ad-4c7bec5c1366.png)
