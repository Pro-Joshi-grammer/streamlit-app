# %% [markdown]
# Introduction to GENAI 102

# %% [raw]
# LLMS are subset of Deep Learning
# Large Language models refers to large general purpose language models that can be pretrained models and then fine tune for specific purposes

# %% [raw]
# pretrain a model with a large dataset then finetune the model with the smaller dataset

# %% [raw]
# LLM usecases
# language translation
# text classification
# sentence completion
# question answering

# %% [raw]
# llm offer decent performance with little domain training it can even be used for few shots and zero shots
# few shots refers to training a model with minimal data
# zero shot refers to model recognizing things that explicitely have not been taught before

# %% [raw]
# Question Answering (QA) in Natural Language Processing (NLP)
# QA is a subset in NLP that deals with the task of automatically answering questions posed in nlp
# QA systems are able to answer a wide range of questions including factual definition and opinion based question

# %% [raw]
#  Prompt design is the process of creating a prompt that is tailored to the specific task that the system is being asked to perform
# eg translate the following text into french
# the llm while giving the answer should specify both the english text with sub heading and french with subheading
# English:
# /* some text in english */
# french
# /*text in french*/
#
# Prompt Engineering is the process of designing prompt that is designed to improve performance
# exapple provodong domain specific knowledge providing output examples

# %% [raw]
# Three types of large language models
# generic llm
# instruction tuned
# dialog tuned

# %% [raw]
# generic model:
# also raw llm model predicts the next word based on the language in the training data

# %% [markdown]
#  ![image.png](attachment:762bbc01-e39f-42b9-87dd-78b1ca6f1a26.png)

# %% [raw]
# Instruction tuned:
# Trained to predict a response to the instructions given in the output
#
# example
# summarize text of 'topic'
# generate an image in ghibili style

# %% [raw]
# Dialog tuned mode :
# Trained to have a dialog by predicting the next response

# %% [raw]
# Tuning :
# The process of adapting a model to a new domain or set of custom use cases by training the model on new data

# %% [raw]
#  Parameter Efficient tuning method(PETM):
# methods for tuning an LLM on your own custom data without duplicating the model
# simply adding more weights to the existing model

# %% [raw]
# ---
# # Introduction to Large Language Models (LLMs)
# **Time Interval:** 00:00 – 13:45
#
# ## 🧠 **What Are LLMs?** – Basics and Overview
# - **Large Language Models (LLMs)** are a subset of deep learning and overlap with generative AI. Their purpose is to generate content such as text, images, or audio.
# - The term **"large"** refers both to the volume of training data (often in the petabyte range) and to the number of parameters, which represent the model’s internalized knowledge.
#
# ## 🧩 **Pretraining & Finetuning** – Two Training Phases
# - LLMs are first **pretrained** on general data, similar to a dog receiving basic training.
# - Then comes **finetuning** for specific tasks or industries (e.g., finance or retail) using relatively small, specialized datasets.
#
# ## 🔄 **Generally Applicable** – Versatility Is Key
# - LLMs are **broadly applicable**, as language patterns are often similar. Only a few organizations can train them from scratch – the rest build on top.
# - One model can perform tasks such as translation, text classification, question answering, or text generation – often with just a little extra training (few-shot learning).
#
# Would you like me to continue summarizing the next part of the video?

# %% [markdown]
# ![image.png](attachment:948091d4-f223-4efb-bc12-855cd1f8b431.png)
