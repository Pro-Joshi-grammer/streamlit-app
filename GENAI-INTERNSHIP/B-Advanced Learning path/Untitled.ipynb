# %% [markdown]
# ATTENTION MECHANISM

# %% [raw]
# For translation we can use encoder decoder mechanism

# %% [raw]
# for some examples such as
# Black cat
# Blue sea
# the translation may not be very accurate as the mechanism foucses more on
# Black instead of cat
# Blue instead of sea
# leading to inefficieny in translations

# %% [raw]
# "The animal didn't cross the street because it was too tired."
#
# To understand what "it" refers to, you pay more attention to "animal" than "street".

# %% [raw]
# A neural network with attention will learn to assign higher weights to important words like "animal" in this context.

# %% [raw]
#  In the Transformer Encoder:
# The encoder uses self-attention.
#
# Each word in the input sequence looks at (pays attention to) all other words in the input.
#
# This helps it build a contextual representation for every word.
#
# 🧠 Example: In the sentence "The cat sat on the mat", the word "cat" might pay attention to "sat" or "mat" depending on context.
#
# 🔶 In the Transformer Decoder:
# The decoder uses two types of attention:
#
# Masked self-attention:
#
# Looks only at previous words (not future ones).
#
# This is to preserve the left-to-right generation process.
#
# Useful during text generation.
#
# Cross-attention (aka encoder-decoder attention):
#
# Here’s where the decoder pays attention to the encoder’s output.
#
# So now, the decoder is saying: “Hey, based on what the encoder said, what should I generate next?”
#
# 🧠 Example: In translation:
#
# Encoder processes the English sentence: “I love apples.”
#
# Decoder pays attention to that info to produce the French sentence: “J’adore les pommes.”
#
# 🧩 Summary:
# Component                	Type of Attention	             Purpose
# Encoder                     	Self-attention	            Learn contextual embeddings of input
# Decoder	Masked                self-attention	            Generate output step-by-step
# Decoder             	Encoder-decoder (cross) attention	Align output with input (like in translation)

# %% [markdown]
# ![Attention mechanism.png](attachment:8f1834cb-0c20-4f44-8d75-80217f0ea13e.png)
