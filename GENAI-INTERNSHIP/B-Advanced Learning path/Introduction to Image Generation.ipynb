# %% [markdown]
# Introduction to Image Generation

# %% [raw]
# Image Generation model families

# %% [raw]
# Variational encoders (VAEs): Encodes images to a compressed size,then decode them back to the original size while distribution of the data

# %% [raw]
# A Generative Adversarial Network (GAN) is a type of artificial intelligence framework that is used for unsupervised learning. GANs are made up of two neural networks: a Generator and a Discriminator. GANs use adversarial training to produce artificial data that resembles the actual data.
#
# GANs can be divided to have three components −
#
# Generative − This component focuses on learning how to generate new data by understanding the underlying patterns in the dataset.
# Adversarial − In simple terms, "adversarial" means setting two things in opposition. In GANs, the generated data is compared to real data from the dataset. This is done using a model trained to distinguish between real and fake data. This model is known as discriminator.
# Networks − To enable the learning process, GANs uses deep neural networks.

# %% [markdown]
# ![generative-model-architecture.png](attachment:85eac7d7-a2ce-4c48-a421-757ec6576d98.png)

# %% [raw]
# AutoRegressive models:
# Generate images by treating an image as a sequence if pixels

# %% [raw]
# Difusion models:
# Diffusion Models are generative models, meaning that they are used to generate data similar to the data on which they are trained. Fundamentally, Diffusion Models work by destroying training data through the successive addition of Gaussian noise, and then learning to recover the data by reversing this noising process. After training, we can use the Diffusion Model to generate data by simply passing randomly sampled noise through the learned denoising process.

# %% [raw]
# Unconditional generation:
# Human face synthesis
# Super position

# %% [raw]
# Conditioned generation:
# Text to image : Mona lisa with cat face
# Image inpainting: Remove the woman from the image
# Text guided image to image: Disco dancer with colorful lights

# %% [raw]
# Diffusion model :
# Destroy structure in a data distribution through an iterative forward diffusion process
# Learn to reverse diffusion process that restores structure in data

# %% [markdown]
# ![image.png](attachment:f14415f3-c91e-41bf-b49b-a411db04fee4.png)

# %% [raw]
# Denoising  diffusion probabilistic models (DDPM)
# Take an image state (t)
# add noise (t1)
# itteratively add noise
# pure state noise (t1000)
# itteratively (t1000-1)
# itteratively remove noise(t)

# %% [raw]
# DDPM training
