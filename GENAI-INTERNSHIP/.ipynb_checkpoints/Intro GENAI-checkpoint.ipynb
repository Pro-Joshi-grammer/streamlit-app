# %% [markdown]
# Intoduction to GENAI 101

# %% [raw]
# Generative AI is a type of artificial intelligence technology that can produce various types of content, including text, imagery, audio, and synthetic data.

# %% [raw]
# AI is a branch of computer science that deals with the creation of intelligent agents, and are systems that can reason, learn, and act autonomously.

# %% [raw]
# Machine learning, is a subfield of AI.
# It is a program or system that trains a model from input data.
# The trained model can make useful predictions from new (never-before-seen) data drawn from the same one used to train the model.
# This means that machine learning gives the computer the ability to learn without explicit programming.

# %% [raw]
# ML
# ->Supervised
# ->unsupervised
# ->reinforcement
# ->Deep Learning

# %% [raw]
# Deep Learning is a subset of ML that uses artificial neural networks allowing them to process more complex data than ml

# %% [markdown]
# ![image.png](attachment:52c7ca38-afcc-465f-be9a-d66209b05f2c.png)

# %% [raw]
# Deep Learning has many layers which allows it to learn both supervised and unsupervised learning
# Deep learning is also called semisupervised learning
# Neural networks can use both supervised and unsupervised data to learn from
# It is trained on some amount of labeled data and a large amount of unlabeled data
# The labeled data helps the neural network to learn the basic concepts of the tasks, while the unlabeled data helps the neural network to generalize to new examples.

# %% [markdown]
# ![image.png](attachment:ef266b58-7d32-4655-92f8-6a81d2c5b5e6.png)

# %% [raw]
# Gen AI is a subset of Deep Learning meaning it uses Artificial Neural Networks to process both labeled data and unlabeled data using supervised learning,unsupervised learning and semi supervised learning

# %% [markdown]
# ![image.png](attachment:22e25ce3-3425-408a-a48b-b503b11edf56.png)

# %% [raw]
# Deep learning models can be divided into two generative and disciminative models

# %% [raw]
# A discriminative deep learning model is a type of machine learning model that aims to classify or predict the
# output category for an input sample. whether a cat or a dog either a boy or a girl.
# Discriminative models are often used in tasks such as classification and regression.
# Example: A common example of a discriminative deep learning model is a convolutional neural network (CNN) used for image classification.
# The CNN takes an image as input and predicts the class label (e.g., cat vs. dog, or different object classes).

# %% [raw]
# Generative Deep Learning Model:
# A generative deep learning model, on the other hand, aims to generate new samples similar to those in a dataset by
# learning the underlying generative process that produced the data.
# Generative models are particularly useful when working with unsupervised or semi-supervised tasks, where the ground truth labels for the data may not be available. These models can be trained using various approaches, including variational autoencoders (VAEs), generative adversarial networks (GANs), and normalizing flows.

# %% [raw]
# discriminative model discriminate between different data instances such as classifying dog and cat.
# A generative model predicts dog and generates new image or similar images of dog.
# Discriminative model discriminates generative model generates

# %% [raw]
# Gen AI or not
# it is not when output generated
#     is a class
#     is a number
#     is a probablility
# It is when output generated
#     is a natural language
#     ia an image
#     is an video

# %% [raw]
# a model is mathematically defined like this
# y=f(x)
#     where f is the model
#     x is the input data
#     y is the output

# %% [raw]
# generative AI process can take training code, labeled data, and unlabeled data of all data types and build a “foundation model”.
# The foundation model can then generate new content.
# It can generate text, code, images, audio, video, and more.

# %% [raw]
# For example models like chatgpt uses very large amounts of data to train their foundational models

# %% [raw]
# GenAI is a type of Artificial Intelligence that creates new content based on what it has learned from existing content.
# The process of learning from existing content is called training and results in the creation of a statistical model.
# When given a prompt, GenAI uses this statistical model to predict what an expected response might be–and this generates new content.
# It learns the underlying structure of the data and can then generate new samples that are similar to the data it was trained on.

# %% [raw]
# A generative language model takes text as input and can output more text, an image, audio, or decisions.

# %% [raw]
# Transformers produced the 2018 revolution in Natural Language Processing.
# At a high-level, a transformer model consists of an encoder and a decoder.
# The encoder encodes the input sequence and passes it to the decoder, which learns how to decode the representations for a relevant task.

# %% [raw]
# different models
#
# Text-to-text:
# models take a natural language input and produce text output.These models are trained to learn the mapping between a pair of texts.
# For example, translating from one language to others.
#
# Text-to-image:
# Text-to-image models are trained on a large set of images, each captioned with a short text description.
# Diffusion is one method used to achieve this.
#
# text-to-video and text-to-3D:
# Text-to-video models aim to generate a video representation from text input.
# The input text can be anything from a single sentence to a full script, and the output is a video that corresponds to the input text.
#
# Text-to-task :
# models are trained to perform a defined task or action based on text input.
# This task can be a wide range of actions such as answering a question, performing a search, making a prediction, or taking some sort of action.
# For example, a text-to-task model could be trained to navigate a web user interface or make changes to a doc through a graphical user interface.
#
# Another model that's larger than those I mentioned is a foundation model, which is a large AI model pre-trained on a vast quantity
# of data "designed to be adapted” (or fine-tuned) to a wide range of downstream tasks, such as sentiment analysis, image captioning, and object recognition.
#
# Foundation models:
# have the potential to revolutionize many industries, including healthcare, finance, and customer service.
# They can even be used to detect fraud and provide personalized customer support.
# If you're looking for foundation models, Vertex AI offers a Model Garden that includes Foundation Models.
# The language Foundation Models include chat, text, and code.
# The Vision Foundation models includes stable diffusion, which has been shown to be effective at generating high-quality images from text descriptions.

# %% [markdown]
# ![image.png](attachment:2518fdd8-3983-470c-a392-a068c6b446ba.png)

# %% [raw]
# Vertex AI Studio lets you quickly explore and customize generative AI models that you can leverage in your applications on Google Cloud.
# Vertex AI Studio helps developers create and deploy generative AI models by providing a variety of tools and resources that make it easy to get started.
# For example, there is a: library of pre-trained models, tool for fine-tuning models, tool for deploying models to production, and community forum for developers to share ideas and collaborate.
#
# Vertex AI can help you create your own: chatbots, digital assistants, custom search engines, knowledge bases, training applications, and more.

# %% [markdown]
# ![image.png](attachment:02103c37-bb30-4d51-b531-70007fe5cddb.png)
